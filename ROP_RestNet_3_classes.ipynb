# %%
import os
import time
import torch
import zipfile
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torchvision.models as models

from torch.cuda import amp
from google.colab import drive
from torchsummary import summary
from PIL import Image, ImageFile
from torchvision import transforms
from torchvision.io import read_image
from tqdm.notebook import tqdm, trange
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import precision_score, recall_score, accuracy_score

ImageFile.LOAD_TRUNCATED_IMAGES = True

import warnings
warnings.filterwarnings('ignore')

# %%
drive.mount('/content/drive')

zip_file_path = '/content/drive/MyDrive/Colab Notebooks/KULIAH/PRAKTIKUM/annotations_3_classes.zip'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall()
# Out:
# Mounted at /content/drive

# %%
class ROP_Dataset(Dataset):
    def __init__(self, txt_file, image_dir, transform=None):
        self.image_list = pd.read_csv(txt_file, header=None)
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_list.iloc[idx, 0])
        image = Image.open(img_path)
        img_tag = self.image_list.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)
        sample = {"image": image, "tag": img_tag}

        return image, img_tag

# %%
MEAN = torch.tensor((0.485, 0.456, 0.406))
STD  = torch.tensor((0.229, 0.224, 0.225))

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=MEAN, std=STD)
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomRotation(15),
    # transforms.Normalize((0.5,), (0.5,))
])

# %%
# Create Dataset Training
dataset_train = ROP_Dataset(txt_file='./annotations/train_3classes.txt', image_dir='./annotations/images', transform=transform)
# Create Dataset Testing
dataset_test = ROP_Dataset(txt_file='./annotations/test_3classes.txt', image_dir='./annotations/images', transform=transform)
# Create Dataset Validation
dataset_valid = ROP_Dataset(txt_file='./annotations/valid_3classes.txt', image_dir='./annotations/images', transform=transform)

# DataLoader Training
dataloader_train = DataLoader(dataset_train, batch_size=32, shuffle=True)
# DataLoader Testing
dataloader_test = DataLoader(dataset_test, batch_size=32, shuffle=True)
# DataLoader Validation
dataloader_valid = DataLoader(dataset_valid, batch_size=32, shuffle=True)

print(dataloader_train)
print(dataloader_test)
print(dataloader_valid)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7bb2733ad750>
# <torch.utils.data.dataloader.DataLoader object at 0x7bb2733ade10>
# <torch.utils.data.dataloader.DataLoader object at 0x7bb2733ad6f0>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using {device} for inference')
# Out:
# Using cuda for inference

# %%
class ResNetModel(nn.Module):
    def __init__(self, num_classes):
        super(ResNetModel, self).__init__()
        self.resnet = models.resnet18(pretrained=True)
        # self.resnet = models.resnet18(weights=None)
        num_ftrs = self.resnet.fc.in_features
        self.resnet.fc = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.resnet(x)

# %%
# Define model, criterion, and optimizer
num_classes = 3 # Healthy, Stage 2-3, & Plus
model = ResNetModel(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:01<00:00, 36.6MB/s]

# %%
def run_model(learningRate, num_epochs):
  # Define Adam optimizer with the current learning rate
  optimizer = optim.Adam(model.parameters(), lr=learningRate)

  # Training loop
  for epoch in range(num_epochs):
      model.train()
      running_loss = 0.0
      all_labels = []
      all_predictions = []
      for inputs, labels in dataloader_train:
          inputs, labels = inputs.to(device), labels.to(device)

          optimizer.zero_grad()

          outputs = model(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          running_loss += loss.item() * inputs.size(0)

          _, predicted = torch.max(outputs, 1)
          all_labels.extend(labels.cpu().numpy())
          all_predictions.extend(predicted.cpu().numpy())

      # Calculate average training loss per epoch
      epoch_loss = running_loss / len(dataset_train)
      precision = precision_score(all_labels, all_predictions, average='weighted')
      recall = recall_score(all_labels, all_predictions, average='weighted')
      accuracy = accuracy_score(all_labels, all_predictions)
      print(f"Training - Learning Rate: {learningRate} - Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Recall: {recall:.4f}, Precision: {precision:.4f}, Accuracy: {accuracy:.4f}")

  # Evaluation loop
  model.eval()
  all_labels = []
  all_predictions = []
  with torch.no_grad():
      for inputs, labels in dataloader_valid:
          inputs, labels = inputs.to(device), labels.to(device)

          outputs = model(inputs)

          _, predicted = torch.max(outputs, 1)
          all_labels.extend(labels.cpu().numpy())
          all_predictions.extend(predicted.cpu().numpy())

  precision = precision_score(all_labels, all_predictions, average='weighted')
  recall = recall_score(all_labels, all_predictions, average='weighted')
  accuracy = accuracy_score(all_labels, all_predictions)
  print(f"\n\nValidation - Learning Rate: {learningRate}, Recall: {recall:.4f}, Precision: {precision:.4f}, Accuracy: {accuracy:.4f}\n\n")

  torch.save(model.state_dict(), f'resnet_model_lr_{learningRate}.pth')

  # Testing loop
  # Set model to evaluation mode
  model.eval()

  # Lists to store true labels and predicted labels
  all_labels = []
  all_predictions = []

  # Loop through the test dataset
  with torch.no_grad():
      for inputs, labels in dataloader_test:
          inputs, labels = inputs.to(device), labels.to(device)

          # Forward pass
          outputs = model(inputs)

          # Get predicted labels
          _, predicted = torch.max(outputs, 1)

          # Append true labels and predicted labels
          all_labels.extend(labels.cpu().numpy())
          all_predictions.extend(predicted.cpu().numpy())

  # Calculate precision, recall, and accuracy
  precision = precision_score(all_labels, all_predictions, average='weighted')
  recall = recall_score(all_labels, all_predictions, average='weighted')
  accuracy = accuracy_score(all_labels, all_predictions)

  print(f"Testing - Learning Rate: {learningRate}, Recall: {recall:.4f}, Precision: {precision:.4f}, Accuracy: {accuracy:.4f}\n\n")

# %%
# Define learning rates
learning_rates = [0.001, 0.005, 0.010, 0.020, 0.030, 0.050, 0.08]

# %%
num_epochs = 50

for lr in learning_rates:
  run_model(lr, num_epochs)
# Out:
# Training - Learning Rate: 0.001 - Epoch 1/50, Training Loss: 0.9291, Recall: 0.6715, Precision: 0.6562, Accuracy: 0.6715
# Training - Learning Rate: 0.001 - Epoch 2/50, Training Loss: 0.4992, Recall: 0.7965, Precision: 0.7922, Accuracy: 0.7965
# Training - Learning Rate: 0.001 - Epoch 3/50, Training Loss: 0.3101, Recall: 0.8779, Precision: 0.8774, Accuracy: 0.8779
# Training - Learning Rate: 0.001 - Epoch 4/50, Training Loss: 0.2239, Recall: 0.9099, Precision: 0.9098, Accuracy: 0.9099
# Training - Learning Rate: 0.001 - Epoch 5/50, Training Loss: 0.2007, Recall: 0.9273, Precision: 0.9275, Accuracy: 0.9273
# Training - Learning Rate: 0.001 - Epoch 6/50, Training Loss: 0.1386, Recall: 0.9419, Precision: 0.9418, Accuracy: 0.9419
# Training - Learning Rate: 0.001 - Epoch 7/50, Training Loss: 0.0834, Recall: 0.9680, Precision: 0.9680, Accuracy: 0.9680
# Training - Learning Rate: 0.001 - Epoch 8/50, Training Loss: 0.1508, Recall: 0.9448, Precision: 0.9450, Accuracy: 0.9448
# Training - Learning Rate: 0.001 - Epoch 9/50, Training Loss: 0.1174, Recall: 0.9535, Precision: 0.9536, Accuracy: 0.9535
# Training - Learning Rate: 0.001 - Epoch 10/50, Training Loss: 0.1542, Recall: 0.9535, Precision: 0.9535, Accuracy: 0.9535
# Training - Learning Rate: 0.001 - Epoch 11/50, Training Loss: 0.0776, Recall: 0.9797, Precision: 0.9797, Accuracy: 0.9797
# Training - Learning Rate: 0.001 - Epoch 12/50, Training Loss: 0.1146, Recall: 0.9738, Precision: 0.9738, Accuracy: 0.9738
# Training - Learning Rate: 0.001 - Epoch 13/50, Training Loss: 0.0730, Recall: 0.9797, Precision: 0.9797, Accuracy: 0.9797
# Training - Learning Rate: 0.001 - Epoch 14/50, Training Loss: 0.0535, Recall: 0.9797, Precision: 0.9799, Accuracy: 0.9797
# Training - Learning Rate: 0.001 - Epoch 15/50, Training Loss: 0.0646, Recall: 0.9767, Precision: 0.9767, Accuracy: 0.9767
# Training - Learning Rate: 0.001 - Epoch 16/50, Training Loss: 0.0525, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.001 - Epoch 17/50, Training Loss: 0.0496, Recall: 0.9738, Precision: 0.9737, Accuracy: 0.9738
# Training - Learning Rate: 0.001 - Epoch 18/50, Training Loss: 0.0640, Recall: 0.9826, Precision: 0.9829, Accuracy: 0.9826
# Training - Learning Rate: 0.001 - Epoch 19/50, Training Loss: 0.0377, Recall: 0.9884, Precision: 0.9885, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 20/50, Training Loss: 0.0529, Recall: 0.9738, Precision: 0.9738, Accuracy: 0.9738
# Training - Learning Rate: 0.001 - Epoch 21/50, Training Loss: 0.0635, Recall: 0.9826, Precision: 0.9827, Accuracy: 0.9826
# Training - Learning Rate: 0.001 - Epoch 22/50, Training Loss: 0.1479, Recall: 0.9448, Precision: 0.9454, Accuracy: 0.9448
# Training - Learning Rate: 0.001 - Epoch 23/50, Training Loss: 0.1649, Recall: 0.9244, Precision: 0.9271, Accuracy: 0.9244
# Training - Learning Rate: 0.001 - Epoch 24/50, Training Loss: 0.1194, Recall: 0.9680, Precision: 0.9680, Accuracy: 0.9680
# Training - Learning Rate: 0.001 - Epoch 25/50, Training Loss: 0.1069, Recall: 0.9680, Precision: 0.9682, Accuracy: 0.9680
# Training - Learning Rate: 0.001 - Epoch 26/50, Training Loss: 0.0636, Recall: 0.9709, Precision: 0.9710, Accuracy: 0.9709
# Training - Learning Rate: 0.001 - Epoch 27/50, Training Loss: 0.0603, Recall: 0.9797, Precision: 0.9799, Accuracy: 0.9797
# Training - Learning Rate: 0.001 - Epoch 28/50, Training Loss: 0.0237, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.001 - Epoch 29/50, Training Loss: 0.0376, Recall: 0.9884, Precision: 0.9887, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 30/50, Training Loss: 0.0627, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 31/50, Training Loss: 0.0209, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.001 - Epoch 32/50, Training Loss: 0.0323, Recall: 0.9884, Precision: 0.9885, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 33/50, Training Loss: 0.0210, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 34/50, Training Loss: 0.0292, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 35/50, Training Loss: 0.0394, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.001 - Epoch 36/50, Training Loss: 0.0375, Recall: 0.9855, Precision: 0.9859, Accuracy: 0.9855
# Training - Learning Rate: 0.001 - Epoch 37/50, Training Loss: 0.0310, Recall: 0.9855, Precision: 0.9858, Accuracy: 0.9855
# Training - Learning Rate: 0.001 - Epoch 38/50, Training Loss: 0.0438, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.001 - Epoch 39/50, Training Loss: 0.0113, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.001 - Epoch 40/50, Training Loss: 0.0207, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 41/50, Training Loss: 0.1149, Recall: 0.9680, Precision: 0.9682, Accuracy: 0.9680
# Training - Learning Rate: 0.001 - Epoch 42/50, Training Loss: 0.0659, Recall: 0.9826, Precision: 0.9827, Accuracy: 0.9826
# Training - Learning Rate: 0.001 - Epoch 43/50, Training Loss: 0.0440, Recall: 0.9826, Precision: 0.9827, Accuracy: 0.9826
# Training - Learning Rate: 0.001 - Epoch 44/50, Training Loss: 0.0854, Recall: 0.9738, Precision: 0.9740, Accuracy: 0.9738
# Training - Learning Rate: 0.001 - Epoch 45/50, Training Loss: 0.0496, Recall: 0.9826, Precision: 0.9826, Accuracy: 0.9826
# Training - Learning Rate: 0.001 - Epoch 46/50, Training Loss: 0.0477, Recall: 0.9767, Precision: 0.9768, Accuracy: 0.9767
# Training - Learning Rate: 0.001 - Epoch 47/50, Training Loss: 0.0346, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.001 - Epoch 48/50, Training Loss: 0.0136, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.001 - Epoch 49/50, Training Loss: 0.0071, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.001 - Epoch 50/50, Training Loss: 0.0039, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
#
#
# Validation - Learning Rate: 0.001, Recall: 0.9804, Precision: 0.9810, Accuracy: 0.9804
#
#
# Testing - Learning Rate: 0.001, Recall: 0.9615, Precision: 0.9622, Accuracy: 0.9615
#
#
# Training - Learning Rate: 0.005 - Epoch 1/50, Training Loss: 1.1408, Recall: 0.6890, Precision: 0.6803, Accuracy: 0.6890
# Training - Learning Rate: 0.005 - Epoch 2/50, Training Loss: 0.6084, Recall: 0.7674, Precision: 0.7826, Accuracy: 0.7674
# Training - Learning Rate: 0.005 - Epoch 3/50, Training Loss: 0.5141, Recall: 0.8081, Precision: 0.8078, Accuracy: 0.8081
# Training - Learning Rate: 0.005 - Epoch 4/50, Training Loss: 0.5274, Recall: 0.7762, Precision: 0.7763, Accuracy: 0.7762
# Training - Learning Rate: 0.005 - Epoch 5/50, Training Loss: 0.4877, Recall: 0.7733, Precision: 0.7726, Accuracy: 0.7733
# Training - Learning Rate: 0.005 - Epoch 6/50, Training Loss: 0.4277, Recall: 0.8459, Precision: 0.8466, Accuracy: 0.8459
# Training - Learning Rate: 0.005 - Epoch 7/50, Training Loss: 0.4718, Recall: 0.7878, Precision: 0.7847, Accuracy: 0.7878
# Training - Learning Rate: 0.005 - Epoch 8/50, Training Loss: 0.4447, Recall: 0.7965, Precision: 0.7959, Accuracy: 0.7965
# Training - Learning Rate: 0.005 - Epoch 9/50, Training Loss: 0.4480, Recall: 0.8140, Precision: 0.8152, Accuracy: 0.8140
# Training - Learning Rate: 0.005 - Epoch 10/50, Training Loss: 0.4059, Recall: 0.8285, Precision: 0.8290, Accuracy: 0.8285
# Training - Learning Rate: 0.005 - Epoch 11/50, Training Loss: 0.3961, Recall: 0.8285, Precision: 0.8298, Accuracy: 0.8285
# Training - Learning Rate: 0.005 - Epoch 12/50, Training Loss: 0.3465, Recall: 0.8750, Precision: 0.8754, Accuracy: 0.8750
# Training - Learning Rate: 0.005 - Epoch 13/50, Training Loss: 0.3404, Recall: 0.8605, Precision: 0.8606, Accuracy: 0.8605
# Training - Learning Rate: 0.005 - Epoch 14/50, Training Loss: 0.3408, Recall: 0.8924, Precision: 0.8952, Accuracy: 0.8924
# Training - Learning Rate: 0.005 - Epoch 15/50, Training Loss: 0.4220, Recall: 0.8198, Precision: 0.8189, Accuracy: 0.8198
# Training - Learning Rate: 0.005 - Epoch 16/50, Training Loss: 0.3734, Recall: 0.8285, Precision: 0.8357, Accuracy: 0.8285
# Training - Learning Rate: 0.005 - Epoch 17/50, Training Loss: 0.3602, Recall: 0.8779, Precision: 0.8776, Accuracy: 0.8779
# Training - Learning Rate: 0.005 - Epoch 18/50, Training Loss: 0.3990, Recall: 0.8430, Precision: 0.8422, Accuracy: 0.8430
# Training - Learning Rate: 0.005 - Epoch 19/50, Training Loss: 0.3555, Recall: 0.8605, Precision: 0.8597, Accuracy: 0.8605
# Training - Learning Rate: 0.005 - Epoch 20/50, Training Loss: 0.2865, Recall: 0.8895, Precision: 0.8902, Accuracy: 0.8895
# Training - Learning Rate: 0.005 - Epoch 21/50, Training Loss: 0.2769, Recall: 0.8983, Precision: 0.9010, Accuracy: 0.8983
# Training - Learning Rate: 0.005 - Epoch 22/50, Training Loss: 0.1756, Recall: 0.9215, Precision: 0.9217, Accuracy: 0.9215
# Training - Learning Rate: 0.005 - Epoch 23/50, Training Loss: 0.2198, Recall: 0.9215, Precision: 0.9216, Accuracy: 0.9215
# Training - Learning Rate: 0.005 - Epoch 24/50, Training Loss: 0.1942, Recall: 0.9244, Precision: 0.9259, Accuracy: 0.9244
# Training - Learning Rate: 0.005 - Epoch 25/50, Training Loss: 0.2194, Recall: 0.9099, Precision: 0.9097, Accuracy: 0.9099
# Training - Learning Rate: 0.005 - Epoch 26/50, Training Loss: 0.2470, Recall: 0.8895, Precision: 0.8892, Accuracy: 0.8895
# Training - Learning Rate: 0.005 - Epoch 27/50, Training Loss: 0.2289, Recall: 0.9157, Precision: 0.9183, Accuracy: 0.9157
# Training - Learning Rate: 0.005 - Epoch 28/50, Training Loss: 0.2441, Recall: 0.8866, Precision: 0.8893, Accuracy: 0.8866
# Training - Learning Rate: 0.005 - Epoch 29/50, Training Loss: 0.1873, Recall: 0.9244, Precision: 0.9264, Accuracy: 0.9244
# Training - Learning Rate: 0.005 - Epoch 30/50, Training Loss: 0.1093, Recall: 0.9535, Precision: 0.9540, Accuracy: 0.9535
# Training - Learning Rate: 0.005 - Epoch 31/50, Training Loss: 0.1908, Recall: 0.9360, Precision: 0.9365, Accuracy: 0.9360
# Training - Learning Rate: 0.005 - Epoch 32/50, Training Loss: 0.1746, Recall: 0.9215, Precision: 0.9226, Accuracy: 0.9215
# Training - Learning Rate: 0.005 - Epoch 33/50, Training Loss: 0.1772, Recall: 0.9390, Precision: 0.9395, Accuracy: 0.9390
# Training - Learning Rate: 0.005 - Epoch 34/50, Training Loss: 0.1645, Recall: 0.9419, Precision: 0.9422, Accuracy: 0.9419
# Training - Learning Rate: 0.005 - Epoch 35/50, Training Loss: 0.1630, Recall: 0.9622, Precision: 0.9638, Accuracy: 0.9622
# Training - Learning Rate: 0.005 - Epoch 36/50, Training Loss: 0.2264, Recall: 0.9041, Precision: 0.9041, Accuracy: 0.9041
# Training - Learning Rate: 0.005 - Epoch 37/50, Training Loss: 0.1565, Recall: 0.9390, Precision: 0.9394, Accuracy: 0.9390
# Training - Learning Rate: 0.005 - Epoch 38/50, Training Loss: 0.0792, Recall: 0.9651, Precision: 0.9658, Accuracy: 0.9651
# Training - Learning Rate: 0.005 - Epoch 39/50, Training Loss: 0.0591, Recall: 0.9826, Precision: 0.9828, Accuracy: 0.9826
# Training - Learning Rate: 0.005 - Epoch 40/50, Training Loss: 0.0477, Recall: 0.9826, Precision: 0.9826, Accuracy: 0.9826
# Training - Learning Rate: 0.005 - Epoch 41/50, Training Loss: 0.0569, Recall: 0.9826, Precision: 0.9829, Accuracy: 0.9826
# Training - Learning Rate: 0.005 - Epoch 42/50, Training Loss: 0.0793, Recall: 0.9738, Precision: 0.9741, Accuracy: 0.9738
# Training - Learning Rate: 0.005 - Epoch 43/50, Training Loss: 0.1363, Recall: 0.9390, Precision: 0.9389, Accuracy: 0.9390
# Training - Learning Rate: 0.005 - Epoch 44/50, Training Loss: 0.2148, Recall: 0.9302, Precision: 0.9299, Accuracy: 0.9302
# Training - Learning Rate: 0.005 - Epoch 45/50, Training Loss: 0.1990, Recall: 0.9331, Precision: 0.9332, Accuracy: 0.9331
# Training - Learning Rate: 0.005 - Epoch 46/50, Training Loss: 0.1184, Recall: 0.9593, Precision: 0.9596, Accuracy: 0.9593
# Training - Learning Rate: 0.005 - Epoch 47/50, Training Loss: 0.1754, Recall: 0.9273, Precision: 0.9272, Accuracy: 0.9273
# Training - Learning Rate: 0.005 - Epoch 48/50, Training Loss: 0.1036, Recall: 0.9680, Precision: 0.9681, Accuracy: 0.9680
# Training - Learning Rate: 0.005 - Epoch 49/50, Training Loss: 0.0764, Recall: 0.9738, Precision: 0.9738, Accuracy: 0.9738
# Training - Learning Rate: 0.005 - Epoch 50/50, Training Loss: 0.0744, Recall: 0.9797, Precision: 0.9796, Accuracy: 0.9797
#
#
# Validation - Learning Rate: 0.005, Recall: 0.7647, Precision: 0.8008, Accuracy: 0.7647
#
#
# Testing - Learning Rate: 0.005, Recall: 0.8942, Precision: 0.9018, Accuracy: 0.8942
#
#
# Training - Learning Rate: 0.01 - Epoch 1/50, Training Loss: 0.9954, Recall: 0.7500, Precision: 0.7490, Accuracy: 0.7500
# Training - Learning Rate: 0.01 - Epoch 2/50, Training Loss: 0.5594, Recall: 0.8052, Precision: 0.8087, Accuracy: 0.8052
# Training - Learning Rate: 0.01 - Epoch 3/50, Training Loss: 0.4578, Recall: 0.8198, Precision: 0.8216, Accuracy: 0.8198
# Training - Learning Rate: 0.01 - Epoch 4/50, Training Loss: 0.3589, Recall: 0.8605, Precision: 0.8634, Accuracy: 0.8605
# Training - Learning Rate: 0.01 - Epoch 5/50, Training Loss: 0.2636, Recall: 0.8924, Precision: 0.8942, Accuracy: 0.8924
# Training - Learning Rate: 0.01 - Epoch 6/50, Training Loss: 0.2737, Recall: 0.8953, Precision: 0.8960, Accuracy: 0.8953
# Training - Learning Rate: 0.01 - Epoch 7/50, Training Loss: 0.1946, Recall: 0.9128, Precision: 0.9160, Accuracy: 0.9128
# Training - Learning Rate: 0.01 - Epoch 8/50, Training Loss: 0.2195, Recall: 0.9186, Precision: 0.9184, Accuracy: 0.9186
# Training - Learning Rate: 0.01 - Epoch 9/50, Training Loss: 0.2190, Recall: 0.9070, Precision: 0.9094, Accuracy: 0.9070
# Training - Learning Rate: 0.01 - Epoch 10/50, Training Loss: 0.2267, Recall: 0.9360, Precision: 0.9360, Accuracy: 0.9360
# Training - Learning Rate: 0.01 - Epoch 11/50, Training Loss: 0.1970, Recall: 0.9215, Precision: 0.9218, Accuracy: 0.9215
# Training - Learning Rate: 0.01 - Epoch 12/50, Training Loss: 0.3376, Recall: 0.8779, Precision: 0.8797, Accuracy: 0.8779
# Training - Learning Rate: 0.01 - Epoch 13/50, Training Loss: 0.2026, Recall: 0.9128, Precision: 0.9136, Accuracy: 0.9128
# Training - Learning Rate: 0.01 - Epoch 14/50, Training Loss: 0.1524, Recall: 0.9360, Precision: 0.9360, Accuracy: 0.9360
# Training - Learning Rate: 0.01 - Epoch 15/50, Training Loss: 0.1272, Recall: 0.9448, Precision: 0.9453, Accuracy: 0.9448
# Training - Learning Rate: 0.01 - Epoch 16/50, Training Loss: 0.1471, Recall: 0.9331, Precision: 0.9334, Accuracy: 0.9331
# Training - Learning Rate: 0.01 - Epoch 17/50, Training Loss: 0.2080, Recall: 0.9186, Precision: 0.9191, Accuracy: 0.9186
# Training - Learning Rate: 0.01 - Epoch 18/50, Training Loss: 0.1624, Recall: 0.9477, Precision: 0.9486, Accuracy: 0.9477
# Training - Learning Rate: 0.01 - Epoch 19/50, Training Loss: 0.0826, Recall: 0.9709, Precision: 0.9710, Accuracy: 0.9709
# Training - Learning Rate: 0.01 - Epoch 20/50, Training Loss: 0.1080, Recall: 0.9651, Precision: 0.9652, Accuracy: 0.9651
# Training - Learning Rate: 0.01 - Epoch 21/50, Training Loss: 0.1362, Recall: 0.9535, Precision: 0.9538, Accuracy: 0.9535
# Training - Learning Rate: 0.01 - Epoch 22/50, Training Loss: 0.1324, Recall: 0.9477, Precision: 0.9476, Accuracy: 0.9477
# Training - Learning Rate: 0.01 - Epoch 23/50, Training Loss: 0.1567, Recall: 0.9331, Precision: 0.9330, Accuracy: 0.9331
# Training - Learning Rate: 0.01 - Epoch 24/50, Training Loss: 0.1287, Recall: 0.9477, Precision: 0.9480, Accuracy: 0.9477
# Training - Learning Rate: 0.01 - Epoch 25/50, Training Loss: 0.0891, Recall: 0.9709, Precision: 0.9709, Accuracy: 0.9709
# Training - Learning Rate: 0.01 - Epoch 26/50, Training Loss: 0.0576, Recall: 0.9826, Precision: 0.9826, Accuracy: 0.9826
# Training - Learning Rate: 0.01 - Epoch 27/50, Training Loss: 0.0568, Recall: 0.9797, Precision: 0.9801, Accuracy: 0.9797
# Training - Learning Rate: 0.01 - Epoch 28/50, Training Loss: 0.0722, Recall: 0.9709, Precision: 0.9713, Accuracy: 0.9709
# Training - Learning Rate: 0.01 - Epoch 29/50, Training Loss: 0.0484, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.01 - Epoch 30/50, Training Loss: 0.0381, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.01 - Epoch 31/50, Training Loss: 0.0559, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.01 - Epoch 32/50, Training Loss: 0.0175, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.01 - Epoch 33/50, Training Loss: 0.0128, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.01 - Epoch 34/50, Training Loss: 0.0127, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.01 - Epoch 35/50, Training Loss: 0.0070, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.01 - Epoch 36/50, Training Loss: 0.0085, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.01 - Epoch 37/50, Training Loss: 0.0306, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.01 - Epoch 38/50, Training Loss: 0.0743, Recall: 0.9651, Precision: 0.9652, Accuracy: 0.9651
# Training - Learning Rate: 0.01 - Epoch 39/50, Training Loss: 0.1358, Recall: 0.9622, Precision: 0.9623, Accuracy: 0.9622
# Training - Learning Rate: 0.01 - Epoch 40/50, Training Loss: 0.0832, Recall: 0.9680, Precision: 0.9683, Accuracy: 0.9680
# Training - Learning Rate: 0.01 - Epoch 41/50, Training Loss: 0.1614, Recall: 0.9593, Precision: 0.9590, Accuracy: 0.9593
# Training - Learning Rate: 0.01 - Epoch 42/50, Training Loss: 0.1066, Recall: 0.9535, Precision: 0.9536, Accuracy: 0.9535
# Training - Learning Rate: 0.01 - Epoch 43/50, Training Loss: 0.1118, Recall: 0.9419, Precision: 0.9430, Accuracy: 0.9419
# Training - Learning Rate: 0.01 - Epoch 44/50, Training Loss: 0.0487, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.01 - Epoch 45/50, Training Loss: 0.0354, Recall: 0.9855, Precision: 0.9855, Accuracy: 0.9855
# Training - Learning Rate: 0.01 - Epoch 46/50, Training Loss: 0.0283, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.01 - Epoch 47/50, Training Loss: 0.0264, Recall: 0.9913, Precision: 0.9915, Accuracy: 0.9913
# Training - Learning Rate: 0.01 - Epoch 48/50, Training Loss: 0.0439, Recall: 0.9826, Precision: 0.9830, Accuracy: 0.9826
# Training - Learning Rate: 0.01 - Epoch 49/50, Training Loss: 0.0690, Recall: 0.9797, Precision: 0.9799, Accuracy: 0.9797
# Training - Learning Rate: 0.01 - Epoch 50/50, Training Loss: 0.0403, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
#
#
# Validation - Learning Rate: 0.01, Recall: 0.8824, Precision: 0.8892, Accuracy: 0.8824
#
#
# Testing - Learning Rate: 0.01, Recall: 0.8750, Precision: 0.8798, Accuracy: 0.8750
#
#
# Training - Learning Rate: 0.02 - Epoch 1/50, Training Loss: 0.7971, Recall: 0.8488, Precision: 0.8488, Accuracy: 0.8488
# Training - Learning Rate: 0.02 - Epoch 2/50, Training Loss: 0.4833, Recall: 0.8256, Precision: 0.8242, Accuracy: 0.8256
# Training - Learning Rate: 0.02 - Epoch 3/50, Training Loss: 0.2832, Recall: 0.9128, Precision: 0.9164, Accuracy: 0.9128
# Training - Learning Rate: 0.02 - Epoch 4/50, Training Loss: 0.2308, Recall: 0.9157, Precision: 0.9180, Accuracy: 0.9157
# Training - Learning Rate: 0.02 - Epoch 5/50, Training Loss: 0.1364, Recall: 0.9448, Precision: 0.9443, Accuracy: 0.9448
# Training - Learning Rate: 0.02 - Epoch 6/50, Training Loss: 0.0676, Recall: 0.9767, Precision: 0.9772, Accuracy: 0.9767
# Training - Learning Rate: 0.02 - Epoch 7/50, Training Loss: 0.1068, Recall: 0.9680, Precision: 0.9682, Accuracy: 0.9680
# Training - Learning Rate: 0.02 - Epoch 8/50, Training Loss: 0.1502, Recall: 0.9506, Precision: 0.9506, Accuracy: 0.9506
# Training - Learning Rate: 0.02 - Epoch 9/50, Training Loss: 0.1551, Recall: 0.9506, Precision: 0.9506, Accuracy: 0.9506
# Training - Learning Rate: 0.02 - Epoch 10/50, Training Loss: 0.1400, Recall: 0.9535, Precision: 0.9537, Accuracy: 0.9535
# Training - Learning Rate: 0.02 - Epoch 11/50, Training Loss: 0.0970, Recall: 0.9535, Precision: 0.9535, Accuracy: 0.9535
# Training - Learning Rate: 0.02 - Epoch 12/50, Training Loss: 0.0998, Recall: 0.9593, Precision: 0.9598, Accuracy: 0.9593
# Training - Learning Rate: 0.02 - Epoch 13/50, Training Loss: 0.0708, Recall: 0.9738, Precision: 0.9739, Accuracy: 0.9738
# Training - Learning Rate: 0.02 - Epoch 14/50, Training Loss: 0.0563, Recall: 0.9797, Precision: 0.9796, Accuracy: 0.9797
# Training - Learning Rate: 0.02 - Epoch 15/50, Training Loss: 0.1052, Recall: 0.9680, Precision: 0.9685, Accuracy: 0.9680
# Training - Learning Rate: 0.02 - Epoch 16/50, Training Loss: 0.1167, Recall: 0.9593, Precision: 0.9598, Accuracy: 0.9593
# Training - Learning Rate: 0.02 - Epoch 17/50, Training Loss: 0.1282, Recall: 0.9360, Precision: 0.9367, Accuracy: 0.9360
# Training - Learning Rate: 0.02 - Epoch 18/50, Training Loss: 0.0760, Recall: 0.9680, Precision: 0.9685, Accuracy: 0.9680
# Training - Learning Rate: 0.02 - Epoch 19/50, Training Loss: 0.1216, Recall: 0.9622, Precision: 0.9633, Accuracy: 0.9622
# Training - Learning Rate: 0.02 - Epoch 20/50, Training Loss: 0.1460, Recall: 0.9564, Precision: 0.9566, Accuracy: 0.9564
# Training - Learning Rate: 0.02 - Epoch 21/50, Training Loss: 0.2003, Recall: 0.9360, Precision: 0.9364, Accuracy: 0.9360
# Training - Learning Rate: 0.02 - Epoch 22/50, Training Loss: 0.1371, Recall: 0.9448, Precision: 0.9451, Accuracy: 0.9448
# Training - Learning Rate: 0.02 - Epoch 23/50, Training Loss: 0.0849, Recall: 0.9709, Precision: 0.9716, Accuracy: 0.9709
# Training - Learning Rate: 0.02 - Epoch 24/50, Training Loss: 0.0807, Recall: 0.9767, Precision: 0.9766, Accuracy: 0.9767
# Training - Learning Rate: 0.02 - Epoch 25/50, Training Loss: 0.0359, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.02 - Epoch 26/50, Training Loss: 0.0410, Recall: 0.9855, Precision: 0.9855, Accuracy: 0.9855
# Training - Learning Rate: 0.02 - Epoch 27/50, Training Loss: 0.0239, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.02 - Epoch 28/50, Training Loss: 0.0295, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.02 - Epoch 29/50, Training Loss: 0.0324, Recall: 0.9913, Precision: 0.9914, Accuracy: 0.9913
# Training - Learning Rate: 0.02 - Epoch 30/50, Training Loss: 0.0474, Recall: 0.9855, Precision: 0.9855, Accuracy: 0.9855
# Training - Learning Rate: 0.02 - Epoch 31/50, Training Loss: 0.0281, Recall: 0.9884, Precision: 0.9885, Accuracy: 0.9884
# Training - Learning Rate: 0.02 - Epoch 32/50, Training Loss: 0.0225, Recall: 0.9913, Precision: 0.9915, Accuracy: 0.9913
# Training - Learning Rate: 0.02 - Epoch 33/50, Training Loss: 0.0189, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.02 - Epoch 34/50, Training Loss: 0.0157, Recall: 0.9942, Precision: 0.9944, Accuracy: 0.9942
# Training - Learning Rate: 0.02 - Epoch 35/50, Training Loss: 0.0156, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.02 - Epoch 36/50, Training Loss: 0.0108, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.02 - Epoch 37/50, Training Loss: 0.0049, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.02 - Epoch 38/50, Training Loss: 0.0060, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.02 - Epoch 39/50, Training Loss: 0.0019, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.02 - Epoch 40/50, Training Loss: 0.0017, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.02 - Epoch 41/50, Training Loss: 0.0038, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.02 - Epoch 42/50, Training Loss: 0.0023, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.02 - Epoch 43/50, Training Loss: 0.0098, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.02 - Epoch 44/50, Training Loss: 0.0139, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.02 - Epoch 45/50, Training Loss: 0.0301, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.02 - Epoch 46/50, Training Loss: 0.0339, Recall: 0.9855, Precision: 0.9855, Accuracy: 0.9855
# Training - Learning Rate: 0.02 - Epoch 47/50, Training Loss: 0.1971, Recall: 0.9564, Precision: 0.9568, Accuracy: 0.9564
# Training - Learning Rate: 0.02 - Epoch 48/50, Training Loss: 0.1973, Recall: 0.9477, Precision: 0.9475, Accuracy: 0.9477
# Training - Learning Rate: 0.02 - Epoch 49/50, Training Loss: 0.1476, Recall: 0.9506, Precision: 0.9506, Accuracy: 0.9506
# Training - Learning Rate: 0.02 - Epoch 50/50, Training Loss: 0.0939, Recall: 0.9767, Precision: 0.9770, Accuracy: 0.9767
#
#
# Validation - Learning Rate: 0.02, Recall: 0.8039, Precision: 0.7985, Accuracy: 0.8039
#
#
# Testing - Learning Rate: 0.02, Recall: 0.8269, Precision: 0.8452, Accuracy: 0.8269
#
#
# Training - Learning Rate: 0.03 - Epoch 1/50, Training Loss: 0.5318, Recall: 0.8634, Precision: 0.8687, Accuracy: 0.8634
# Training - Learning Rate: 0.03 - Epoch 2/50, Training Loss: 0.3325, Recall: 0.8953, Precision: 0.8952, Accuracy: 0.8953
# Training - Learning Rate: 0.03 - Epoch 3/50, Training Loss: 0.1601, Recall: 0.9360, Precision: 0.9358, Accuracy: 0.9360
# Training - Learning Rate: 0.03 - Epoch 4/50, Training Loss: 0.1099, Recall: 0.9622, Precision: 0.9624, Accuracy: 0.9622
# Training - Learning Rate: 0.03 - Epoch 5/50, Training Loss: 0.1691, Recall: 0.9477, Precision: 0.9480, Accuracy: 0.9477
# Training - Learning Rate: 0.03 - Epoch 6/50, Training Loss: 0.2186, Recall: 0.9273, Precision: 0.9268, Accuracy: 0.9273
# Training - Learning Rate: 0.03 - Epoch 7/50, Training Loss: 0.1442, Recall: 0.9593, Precision: 0.9599, Accuracy: 0.9593
# Training - Learning Rate: 0.03 - Epoch 8/50, Training Loss: 0.0958, Recall: 0.9506, Precision: 0.9510, Accuracy: 0.9506
# Training - Learning Rate: 0.03 - Epoch 9/50, Training Loss: 0.1135, Recall: 0.9593, Precision: 0.9597, Accuracy: 0.9593
# Training - Learning Rate: 0.03 - Epoch 10/50, Training Loss: 0.1363, Recall: 0.9651, Precision: 0.9656, Accuracy: 0.9651
# Training - Learning Rate: 0.03 - Epoch 11/50, Training Loss: 0.1536, Recall: 0.9331, Precision: 0.9363, Accuracy: 0.9331
# Training - Learning Rate: 0.03 - Epoch 12/50, Training Loss: 0.1008, Recall: 0.9564, Precision: 0.9565, Accuracy: 0.9564
# Training - Learning Rate: 0.03 - Epoch 13/50, Training Loss: 0.0593, Recall: 0.9767, Precision: 0.9767, Accuracy: 0.9767
# Training - Learning Rate: 0.03 - Epoch 14/50, Training Loss: 0.0613, Recall: 0.9797, Precision: 0.9797, Accuracy: 0.9797
# Training - Learning Rate: 0.03 - Epoch 15/50, Training Loss: 0.0443, Recall: 0.9884, Precision: 0.9885, Accuracy: 0.9884
# Training - Learning Rate: 0.03 - Epoch 16/50, Training Loss: 0.0436, Recall: 0.9738, Precision: 0.9738, Accuracy: 0.9738
# Training - Learning Rate: 0.03 - Epoch 17/50, Training Loss: 0.0274, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.03 - Epoch 18/50, Training Loss: 0.0456, Recall: 0.9797, Precision: 0.9801, Accuracy: 0.9797
# Training - Learning Rate: 0.03 - Epoch 19/50, Training Loss: 0.0681, Recall: 0.9797, Precision: 0.9796, Accuracy: 0.9797
# Training - Learning Rate: 0.03 - Epoch 20/50, Training Loss: 0.0990, Recall: 0.9651, Precision: 0.9656, Accuracy: 0.9651
# Training - Learning Rate: 0.03 - Epoch 21/50, Training Loss: 0.1146, Recall: 0.9593, Precision: 0.9595, Accuracy: 0.9593
# Training - Learning Rate: 0.03 - Epoch 22/50, Training Loss: 0.0690, Recall: 0.9738, Precision: 0.9744, Accuracy: 0.9738
# Training - Learning Rate: 0.03 - Epoch 23/50, Training Loss: 0.0295, Recall: 0.9884, Precision: 0.9885, Accuracy: 0.9884
# Training - Learning Rate: 0.03 - Epoch 24/50, Training Loss: 0.0221, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.03 - Epoch 25/50, Training Loss: 0.0164, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.03 - Epoch 26/50, Training Loss: 0.0301, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.03 - Epoch 27/50, Training Loss: 0.0425, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.03 - Epoch 28/50, Training Loss: 0.0393, Recall: 0.9884, Precision: 0.9887, Accuracy: 0.9884
# Training - Learning Rate: 0.03 - Epoch 29/50, Training Loss: 0.0213, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.03 - Epoch 30/50, Training Loss: 0.1152, Recall: 0.9680, Precision: 0.9680, Accuracy: 0.9680
# Training - Learning Rate: 0.03 - Epoch 31/50, Training Loss: 0.1195, Recall: 0.9593, Precision: 0.9594, Accuracy: 0.9593
# Training - Learning Rate: 0.03 - Epoch 32/50, Training Loss: 0.0318, Recall: 0.9913, Precision: 0.9914, Accuracy: 0.9913
# Training - Learning Rate: 0.03 - Epoch 33/50, Training Loss: 0.0901, Recall: 0.9680, Precision: 0.9682, Accuracy: 0.9680
# Training - Learning Rate: 0.03 - Epoch 34/50, Training Loss: 0.0490, Recall: 0.9767, Precision: 0.9776, Accuracy: 0.9767
# Training - Learning Rate: 0.03 - Epoch 35/50, Training Loss: 0.0619, Recall: 0.9767, Precision: 0.9768, Accuracy: 0.9767
# Training - Learning Rate: 0.03 - Epoch 36/50, Training Loss: 0.1062, Recall: 0.9826, Precision: 0.9826, Accuracy: 0.9826
# Training - Learning Rate: 0.03 - Epoch 37/50, Training Loss: 0.0814, Recall: 0.9767, Precision: 0.9769, Accuracy: 0.9767
# Training - Learning Rate: 0.03 - Epoch 38/50, Training Loss: 0.0287, Recall: 0.9884, Precision: 0.9886, Accuracy: 0.9884
# Training - Learning Rate: 0.03 - Epoch 39/50, Training Loss: 0.0345, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.03 - Epoch 40/50, Training Loss: 0.0156, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.03 - Epoch 41/50, Training Loss: 0.0050, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 42/50, Training Loss: 0.0021, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 43/50, Training Loss: 0.0020, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 44/50, Training Loss: 0.0014, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 45/50, Training Loss: 0.0019, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 46/50, Training Loss: 0.0014, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 47/50, Training Loss: 0.0009, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 48/50, Training Loss: 0.0008, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 49/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.03 - Epoch 50/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
#
#
# Validation - Learning Rate: 0.03, Recall: 0.9412, Precision: 0.9464, Accuracy: 0.9412
#
#
# Testing - Learning Rate: 0.03, Recall: 0.9808, Precision: 0.9814, Accuracy: 0.9808
#
#
# Training - Learning Rate: 0.05 - Epoch 1/50, Training Loss: 0.3348, Recall: 0.9070, Precision: 0.9072, Accuracy: 0.9070
# Training - Learning Rate: 0.05 - Epoch 2/50, Training Loss: 0.2428, Recall: 0.9157, Precision: 0.9156, Accuracy: 0.9157
# Training - Learning Rate: 0.05 - Epoch 3/50, Training Loss: 0.2571, Recall: 0.9186, Precision: 0.9202, Accuracy: 0.9186
# Training - Learning Rate: 0.05 - Epoch 4/50, Training Loss: 0.1614, Recall: 0.9477, Precision: 0.9481, Accuracy: 0.9477
# Training - Learning Rate: 0.05 - Epoch 5/50, Training Loss: 0.1195, Recall: 0.9622, Precision: 0.9626, Accuracy: 0.9622
# Training - Learning Rate: 0.05 - Epoch 6/50, Training Loss: 0.0782, Recall: 0.9709, Precision: 0.9712, Accuracy: 0.9709
# Training - Learning Rate: 0.05 - Epoch 7/50, Training Loss: 0.0292, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 8/50, Training Loss: 0.0474, Recall: 0.9738, Precision: 0.9739, Accuracy: 0.9738
# Training - Learning Rate: 0.05 - Epoch 9/50, Training Loss: 0.1249, Recall: 0.9535, Precision: 0.9533, Accuracy: 0.9535
# Training - Learning Rate: 0.05 - Epoch 10/50, Training Loss: 0.0550, Recall: 0.9738, Precision: 0.9743, Accuracy: 0.9738
# Training - Learning Rate: 0.05 - Epoch 11/50, Training Loss: 0.0803, Recall: 0.9680, Precision: 0.9680, Accuracy: 0.9680
# Training - Learning Rate: 0.05 - Epoch 12/50, Training Loss: 0.0658, Recall: 0.9767, Precision: 0.9769, Accuracy: 0.9767
# Training - Learning Rate: 0.05 - Epoch 13/50, Training Loss: 0.0702, Recall: 0.9767, Precision: 0.9771, Accuracy: 0.9767
# Training - Learning Rate: 0.05 - Epoch 14/50, Training Loss: 0.0487, Recall: 0.9797, Precision: 0.9799, Accuracy: 0.9797
# Training - Learning Rate: 0.05 - Epoch 15/50, Training Loss: 0.1105, Recall: 0.9651, Precision: 0.9652, Accuracy: 0.9651
# Training - Learning Rate: 0.05 - Epoch 16/50, Training Loss: 0.0693, Recall: 0.9680, Precision: 0.9699, Accuracy: 0.9680
# Training - Learning Rate: 0.05 - Epoch 17/50, Training Loss: 0.0465, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.05 - Epoch 18/50, Training Loss: 0.0216, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 19/50, Training Loss: 0.0085, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 20/50, Training Loss: 0.0068, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.05 - Epoch 21/50, Training Loss: 0.0326, Recall: 0.9913, Precision: 0.9912, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 22/50, Training Loss: 0.0436, Recall: 0.9913, Precision: 0.9915, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 23/50, Training Loss: 0.0231, Recall: 0.9913, Precision: 0.9914, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 24/50, Training Loss: 0.0201, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.05 - Epoch 25/50, Training Loss: 0.0264, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.05 - Epoch 26/50, Training Loss: 0.1742, Recall: 0.9680, Precision: 0.9681, Accuracy: 0.9680
# Training - Learning Rate: 0.05 - Epoch 27/50, Training Loss: 0.3668, Recall: 0.9157, Precision: 0.9155, Accuracy: 0.9157
# Training - Learning Rate: 0.05 - Epoch 28/50, Training Loss: 0.1664, Recall: 0.9419, Precision: 0.9460, Accuracy: 0.9419
# Training - Learning Rate: 0.05 - Epoch 29/50, Training Loss: 0.2310, Recall: 0.9099, Precision: 0.9131, Accuracy: 0.9099
# Training - Learning Rate: 0.05 - Epoch 30/50, Training Loss: 0.1164, Recall: 0.9622, Precision: 0.9621, Accuracy: 0.9622
# Training - Learning Rate: 0.05 - Epoch 31/50, Training Loss: 0.0774, Recall: 0.9680, Precision: 0.9686, Accuracy: 0.9680
# Training - Learning Rate: 0.05 - Epoch 32/50, Training Loss: 0.0450, Recall: 0.9826, Precision: 0.9829, Accuracy: 0.9826
# Training - Learning Rate: 0.05 - Epoch 33/50, Training Loss: 0.0193, Recall: 0.9942, Precision: 0.9942, Accuracy: 0.9942
# Training - Learning Rate: 0.05 - Epoch 34/50, Training Loss: 0.0196, Recall: 0.9913, Precision: 0.9918, Accuracy: 0.9913
# Training - Learning Rate: 0.05 - Epoch 35/50, Training Loss: 0.0295, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.05 - Epoch 36/50, Training Loss: 0.0125, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.05 - Epoch 37/50, Training Loss: 0.0147, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.05 - Epoch 38/50, Training Loss: 0.0029, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 39/50, Training Loss: 0.0038, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 40/50, Training Loss: 0.0029, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 41/50, Training Loss: 0.0008, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 42/50, Training Loss: 0.0024, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 43/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 44/50, Training Loss: 0.0005, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 45/50, Training Loss: 0.0006, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 46/50, Training Loss: 0.0001, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 47/50, Training Loss: 0.0002, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 48/50, Training Loss: 0.0002, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 49/50, Training Loss: 0.0002, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.05 - Epoch 50/50, Training Loss: 0.0002, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
#
#
# Validation - Learning Rate: 0.05, Recall: 0.9412, Precision: 0.9464, Accuracy: 0.9412
#
#
# Testing - Learning Rate: 0.05, Recall: 0.9423, Precision: 0.9423, Accuracy: 0.9423
#
#
# Training - Learning Rate: 0.08 - Epoch 1/50, Training Loss: 0.3624, Recall: 0.9302, Precision: 0.9302, Accuracy: 0.9302
# Training - Learning Rate: 0.08 - Epoch 2/50, Training Loss: 0.2499, Recall: 0.9157, Precision: 0.9173, Accuracy: 0.9157
# Training - Learning Rate: 0.08 - Epoch 3/50, Training Loss: 0.1588, Recall: 0.9419, Precision: 0.9418, Accuracy: 0.9419
# Training - Learning Rate: 0.08 - Epoch 4/50, Training Loss: 0.1091, Recall: 0.9477, Precision: 0.9478, Accuracy: 0.9477
# Training - Learning Rate: 0.08 - Epoch 5/50, Training Loss: 0.0978, Recall: 0.9593, Precision: 0.9599, Accuracy: 0.9593
# Training - Learning Rate: 0.08 - Epoch 6/50, Training Loss: 0.0570, Recall: 0.9855, Precision: 0.9856, Accuracy: 0.9855
# Training - Learning Rate: 0.08 - Epoch 7/50, Training Loss: 0.0823, Recall: 0.9680, Precision: 0.9680, Accuracy: 0.9680
# Training - Learning Rate: 0.08 - Epoch 8/50, Training Loss: 0.1295, Recall: 0.9593, Precision: 0.9614, Accuracy: 0.9593
# Training - Learning Rate: 0.08 - Epoch 9/50, Training Loss: 0.5353, Recall: 0.9419, Precision: 0.9417, Accuracy: 0.9419
# Training - Learning Rate: 0.08 - Epoch 10/50, Training Loss: 0.3712, Recall: 0.9041, Precision: 0.9041, Accuracy: 0.9041
# Training - Learning Rate: 0.08 - Epoch 11/50, Training Loss: 0.1925, Recall: 0.9128, Precision: 0.9138, Accuracy: 0.9128
# Training - Learning Rate: 0.08 - Epoch 12/50, Training Loss: 0.1018, Recall: 0.9535, Precision: 0.9545, Accuracy: 0.9535
# Training - Learning Rate: 0.08 - Epoch 13/50, Training Loss: 0.0627, Recall: 0.9738, Precision: 0.9739, Accuracy: 0.9738
# Training - Learning Rate: 0.08 - Epoch 14/50, Training Loss: 0.0792, Recall: 0.9913, Precision: 0.9913, Accuracy: 0.9913
# Training - Learning Rate: 0.08 - Epoch 15/50, Training Loss: 0.0419, Recall: 0.9826, Precision: 0.9826, Accuracy: 0.9826
# Training - Learning Rate: 0.08 - Epoch 16/50, Training Loss: 0.0365, Recall: 0.9855, Precision: 0.9855, Accuracy: 0.9855
# Training - Learning Rate: 0.08 - Epoch 17/50, Training Loss: 0.0755, Recall: 0.9709, Precision: 0.9711, Accuracy: 0.9709
# Training - Learning Rate: 0.08 - Epoch 18/50, Training Loss: 0.1438, Recall: 0.9477, Precision: 0.9477, Accuracy: 0.9477
# Training - Learning Rate: 0.08 - Epoch 19/50, Training Loss: 0.1570, Recall: 0.9535, Precision: 0.9535, Accuracy: 0.9535
# Training - Learning Rate: 0.08 - Epoch 20/50, Training Loss: 0.0983, Recall: 0.9680, Precision: 0.9683, Accuracy: 0.9680
# Training - Learning Rate: 0.08 - Epoch 21/50, Training Loss: 0.0793, Recall: 0.9738, Precision: 0.9741, Accuracy: 0.9738
# Training - Learning Rate: 0.08 - Epoch 22/50, Training Loss: 0.0261, Recall: 0.9884, Precision: 0.9884, Accuracy: 0.9884
# Training - Learning Rate: 0.08 - Epoch 23/50, Training Loss: 0.0102, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.08 - Epoch 24/50, Training Loss: 0.0080, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 25/50, Training Loss: 0.0028, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 26/50, Training Loss: 0.0018, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 27/50, Training Loss: 0.0008, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 28/50, Training Loss: 0.0006, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 29/50, Training Loss: 0.0012, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 30/50, Training Loss: 0.0004, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 31/50, Training Loss: 0.0008, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 32/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 33/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 34/50, Training Loss: 0.0005, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 35/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 36/50, Training Loss: 0.0004, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 37/50, Training Loss: 0.0003, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 38/50, Training Loss: 0.0006, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 39/50, Training Loss: 0.0002, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 40/50, Training Loss: 0.0011, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 41/50, Training Loss: 0.0027, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 42/50, Training Loss: 0.0028, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 43/50, Training Loss: 0.0030, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 44/50, Training Loss: 0.0004, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 45/50, Training Loss: 0.0018, Recall: 1.0000, Precision: 1.0000, Accuracy: 1.0000
# Training - Learning Rate: 0.08 - Epoch 46/50, Training Loss: 0.0050, Recall: 0.9971, Precision: 0.9971, Accuracy: 0.9971
# Training - Learning Rate: 0.08 - Epoch 47/50, Training Loss: 0.0585, Recall: 0.9826, Precision: 0.9844, Accuracy: 0.9826
# Training - Learning Rate: 0.08 - Epoch 48/50, Training Loss: 0.4299, Recall: 0.8953, Precision: 0.8952, Accuracy: 0.8953
# Training - Learning Rate: 0.08 - Epoch 49/50, Training Loss: 0.4509, Recall: 0.8837, Precision: 0.8835, Accuracy: 0.8837
# Training - Learning Rate: 0.08 - Epoch 50/50, Training Loss: 0.1684, Recall: 0.9506, Precision: 0.9505, Accuracy: 0.9506
#
#
# Validation - Learning Rate: 0.08, Recall: 0.7647, Precision: 0.8036, Accuracy: 0.7647
#
#
# Testing - Learning Rate: 0.08, Recall: 0.8077, Precision: 0.8423, Accuracy: 0.8077
